# %%
import bz2
import json
import requests
from io import BytesIO
import csv

test_range = range(5)
set_range = range(51,91)


# Shard URLs
shards = [
    f"https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_{i:02d}.jsonl.bz2"
    for i in set_range
]

# Keywords to search for
refugee_keywords = ["פליטים", "מסתננים","פליט ","מסתנן","מבקשי מקלט","מבקש מקלט","אריתריאה","אריתראה","סודן","סודאן","סודני","סודאני","אריתראי","דרפור"]
violence_keywords = ["מסומם", "מסוממ","תקיפה","לאנוס","אנס","אונס","רצח","סמים","פשיעה","פשע","אלימות"]
exclude = ["חממה","גזים","גזי","ג'נין","שועפאט","שועפט","מכונית","דיזל","בנזין","כלי רכב","מחנה פליטים","מחנה הפליטים"]


# Output CSV file
output_file = "knesset_filtered_sentences_3.csv"

# Open CSV   file for writing
with open(output_file, "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ["shard", "sentence_id", "speaker_name", "sentence_text", "committee"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    # Iterate over all shards
    for shard_idx, url in enumerate(shards):
        shard_name = f"shard_{shard_idx:02d}"
        print(f"Processing {shard_name}: {url}")

        try:
            resp = requests.get(url, stream=True)
            resp.raise_for_status()
        except requests.RequestException as e:
            print(f"Failed to download shard {url}: {e}")
            continue

        # Open bz2 stream
        with bz2.open(BytesIO(resp.content), "rt", encoding="utf-8") as f:
            for line_idx, line in enumerate(f, 1):
                line = line.strip()
                if not line:
                    continue
                try:
                    example = json.loads(line)
                except json.JSONDecodeError:
                    continue  # skip malformed lines

                text = example.get("sentence_text", "")
                if any(k in text for k in refugee_keywords) and any(k in text for k in violence_keywords):
                    if not any(k in text for k in exclude):
                        writer.writerow({
                            "shard": shard_name,
                            "sentence_id": example.get("sentence_id", ""),
                            "speaker_name": example.get("speaker_name", ""),
                            "sentence_text": text
                            #"committee": example.get("committee_name", "")
                        })

        print(f"Finished {shard_name}")
# Out:
# Processing shard_00: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_51.jsonl.bz2
# Finished shard_00
# Processing shard_01: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_52.jsonl.bz2
# Finished shard_01
# Processing shard_02: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_53.jsonl.bz2
# Finished shard_02
# Processing shard_03: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_54.jsonl.bz2
# Finished shard_03
# Processing shard_04: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_55.jsonl.bz2
# Finished shard_04
# Processing shard_05: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_56.jsonl.bz2
# Finished shard_05
# Processing shard_06: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_57.jsonl.bz2
# Finished shard_06
# Processing shard_07: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_58.jsonl.bz2
# Finished shard_07
# Processing shard_08: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_59.jsonl.bz2
# Finished shard_08
# Processing shard_09: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_60.jsonl.bz2
# Finished shard_09
# Processing shard_10: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_61.jsonl.bz2
# Finished shard_10
# Processing shard_11: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_62.jsonl.bz2
# Finished shard_11
# Processing shard_12: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_63.jsonl.bz2
# Finished shard_12
# Processing shard_13: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_64.jsonl.bz2
# Finished shard_13
# Processing shard_14: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_65.jsonl.bz2
# Finished shard_14
# Processing shard_15: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_66.jsonl.bz2
# Finished shard_15
# Processing shard_16: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_67.jsonl.bz2
# Finished shard_16
# Processing shard_17: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_68.jsonl.bz2
# Finished shard_17
# Processing shard_18: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_69.jsonl.bz2
# Finished shard_18
# Processing shard_19: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_70.jsonl.bz2
# Finished shard_19
# Processing shard_20: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_71.jsonl.bz2
# Finished shard_20
# Processing shard_21: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_72.jsonl.bz2
# Finished shard_21
# Processing shard_22: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_73.jsonl.bz2
# Finished shard_22
# Processing shard_23: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_74.jsonl.bz2
# Finished shard_23
# Processing shard_24: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_75.jsonl.bz2
# Finished shard_24
# Processing shard_25: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_76.jsonl.bz2
# Finished shard_25
# Processing shard_26: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_77.jsonl.bz2
# Finished shard_26
# Processing shard_27: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_78.jsonl.bz2
# Finished shard_27
# Processing shard_28: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_79.jsonl.bz2
# Finished shard_28
# Processing shard_29: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_80.jsonl.bz2
# Finished shard_29
# Processing shard_30: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_81.jsonl.bz2
# Finished shard_30
# Processing shard_31: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_82.jsonl.bz2
# Finished shard_31
# Processing shard_32: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_83.jsonl.bz2
# Finished shard_32
# Processing shard_33: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_84.jsonl.bz2
# Finished shard_33
# Processing shard_34: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_85.jsonl.bz2
# Finished shard_34
# Processing shard_35: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_86.jsonl.bz2
# Finished shard_35
# Processing shard_36: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_87.jsonl.bz2
# Finished shard_36
# Processing shard_37: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_88.jsonl.bz2
# Finished shard_37
# Processing shard_38: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_89.jsonl.bz2
# Finished shard_38
# Processing shard_39: https://huggingface.co/datasets/HaifaCLGroup/KnessetCorpus/resolve/main/protocols_sentences/committee_full_sentences_shards_bzip2_files/committee_full_sentences_shard_90.jsonl.bz2
# Finished shard_39
